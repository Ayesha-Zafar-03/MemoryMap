# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Zafar-03/MemoryMap/blob/main/MemoryMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hackathon

# %%
# --- MEMORYMAP PROJECT STRUCTURE SETUP FOR HACK4HEALTH ---

# Step 1: Create main project folder and move into it
import os

project_name = "memorymap"
if not os.path.exists(project_name):
    os.makedirs(project_name)
os.chdir(project_name)

# Step 2: Create subfolders
subfolders = ["data", "notebooks", "models", "reports", "utils"]
for folder in subfolders:
    if not os.path.exists(folder):
        os.makedirs(folder)

# Step 3: Create README.md
readme_text = """# MemoryMap 🧠
Early detection of Alzheimer’s Disease using machine learning.
Built for Hack4Health 2025.
"""
with open("README.md", "w") as f:
    f.write(readme_text)

# Step 4: Create requirements.txt
requirements = """pandas
numpy
scikit-learn
matplotlib
seaborn
xgboost
shap
"""
with open("requirements.txt", "w") as f:
    f.write(requirements)

# Step 5: Check structure
# !apt install tree -y  # install tree to visualize directories
# !tree -d -L 2         # show directories up to 2 levels

print("\n✅ Project structure created successfully!")
print(f"📂 Main folder: {os.getcwd()}")
print("You can now save your notebook in 'notebooks/' and start coding.")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (172 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121229 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# .
# ├── data
# ├── models
# ├── notebooks
# ├── reports
# └── utils
#
# 5 directories
#
# ✅ Project structure created successfully!
# 📂 Main folder: /content/memorymap
# You can now save your notebook in 'notebooks/' and start coding.
